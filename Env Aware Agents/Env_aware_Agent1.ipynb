# %%
import random
random.seed(10)

# %%
class random_environment:
    def __init__(self):
        self.property = [];
        a = []
        a.append(1)
        for i in range(1,200):
            a.append(random.randint(1,2))
        self.property = a
        print(self.property)
        print("NEW MAX LIMIT IS: ", len(self.property))
    
    def get_property(self):
        return self.property

# %%
class env_aware_agent:
    def __init__(self):
        self.pos = 0
        
    def move(self):
#         print(self.pos)
        while(self.pos < len(env.get_property())):
            if env.get_property()[self.pos] == 1:
                print("posn after jump ", self.pos, end= " ");print("present posn  ", self.pos, end= " ")
                print("next posn ", env.get_property()[self.pos], end= " ");print("jumped from ", self.pos)
                self.pos += 2
            elif env.get_property()[self.pos] == 2:
                print("posn after walking ", self.pos, end= " ");print("present posn ", self.pos, end= " ")
                print("next position ", env.get_property()[self.pos], end= " ");print("walk started from ", self.pos)
                self.pos += 1

# %%
env = random_environment()
agent = env_aware_agent()
agent.move()
# Out:
# [1, 1, 2, 2, 1, 1, 2, 2, 2, 1, 1, 2, 2, 1, 1, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 1, 2, 2, 1, 1, 1, 1, 1, 2, 2, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 1, 1, 1, 2, 2, 1, 1, 1, 2, 2, 1, 1, 1, 2, 1, 1, 2, 2, 2, 2, 1, 2, 1, 1, 1, 2, 2, 2, 1, 1, 1, 2, 2, 2, 2, 1, 1, 1, 2, 2, 1, 1, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1, 1, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 1, 2, 1, 1, 2, 1, 1, 2, 1, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 1, 1, 2, 1, 1, 2, 2, 1, 2, 1, 1, 1, 2, 1, 2, 1, 2, 2, 1, 2, 1, 1, 1, 2, 1, 1, 2, 2, 2, 2, 1, 2, 2, 1, 1, 1, 2, 2, 2, 1, 1, 2, 1, 1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# NEW MAX LIMIT IS:  200
# posn after jump  0 present posn   0 next posn  1 jumped from  0
# posn after walking  2 present posn  2 next position  2 walk started from  2
# posn after walking  3 present posn  3 next position  2 walk started from  3
# posn after jump  4 present posn   4 next posn  1 jumped from  4
# posn after walking  6 present posn  6 next position  2 walk started from  6
# ...
