# %%
from numpy.random import randint

# %%
class random_environment:
    def __init__(self):
        self.property = [];
        self.property = randint(1, 4, 200)
        print(self.property)
        print("NEW MAX LIMIT IS: ", len(self.property))
    
    def get_property(self):
        return self.property

# %%
class env_aware_agent:
    def __init__(self):
        self.pos = 0
        
    def move(self):
        while(self.pos < len(env.get_property())):
            if env.get_property()[self.pos] == 1:
                print("** EATING_SWEET **")
            elif env.get_property()[self.pos] == 2:
                print("** WALKING **")
            elif env.get_property()[self.pos] == 3:
                if env.get_property()[self.pos-1]== 0 and env.get_property()[self.pos-2] == 0 :
                    print("** EATING_TANGY **")
                else :
                    print("** JUMPING_TANGY")
            self.pos +=1

# %%
env = random_environment()
agent = env_aware_agent()
agent.move()
# Out:
# [3 1 1 1 3 1 1 3 1 2 1 3 1 1 1 2 3 1 1 2 1 2 3 2 1 3 1 2 1 2 3 3 3 3 3 1 1
#  3 2 3 2 2 2 2 3 1 3 2 1 3 1 3 1 3 3 2 3 2 3 2 2 1 3 3 2 3 3 3 3 3 1 3 2 2
#  2 1 3 1 1 2 2 2 2 2 1 1 1 3 3 3 3 3 2 3 1 3 1 1 3 3 1 3 3 1 1 2 3 3 3 1 1
#  1 3 2 3 2 2 2 3 1 2 3 2 1 2 2 1 2 2 1 2 1 3 1 1 2 2 1 3 1 2 1 2 3 2 2 2 1
#  3 3 2 3 3 2 2 3 2 3 1 2 2 3 2 3 3 2 1 3 3 1 2 1 3 2 1 1 3 2 1 3 2 1 2 2 3
#  1 2 1 1 3 3 3 2 2 1 1 3 1 3 2]
# NEW MAX LIMIT IS:  200
# ** JUMPING_TANGY
# ** EATING_SWEET **
# ** EATING_SWEET **
# ** EATING_SWEET **
# ** JUMPING_TANGY
# ** EATING_SWEET **
# ** EATING_SWEET **
# ** JUMPING_TANGY
# ** EATING_SWEET **
# ** WALKING **
# ** EATING_SWEET **
# ** JUMPING_TANGY
# ** EATING_SWEET **
# ** EATING_SWEET **
# ** EATING_SWEET **
# ** WALKING **
# ** JUMPING_TANGY
# ** EATING_SWEET **
# ** EATING_SWEET **
# ** WALKING **
# ** EATING_SWEET **
# ** WALKING **
# ** JUMPING_TANGY
# ** WALKING **
# ** EATING_SWEET **
# ** JUMPING_TANGY
# ** EATING_SWEET **
# ** WALKING **
# ...
